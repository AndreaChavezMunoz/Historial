# %% [markdown]
# To covert to script
# jupyter nbconvert somenotebook.ipynb --to script

# %%
# Import data
from __future__ import print_function
import os.path
import pandas as pd
from google.auth.transport.requests import Request
from google.oauth2.credentials import Credentials
from google_auth_oauthlib.flow import InstalledAppFlow
from googleapiclient.discovery import build
from _general import clean_text
import spacy
import subprocess
import sys
from gensim.models.word2vec import Word2Vec
from gensim.models.keyedvectors import KeyedVectors
import multiprocessing
import numpy as np
from tqdm import tqdm
from annoy import AnnoyIndex
import json

# %%
# CONECTARSE A BASE DE DATOS 
# Could be cached
def connect_sheet(credentials):
    # If modifying these scopes, delete the file token.json.
    SCOPES = ['https://www.googleapis.com/auth/spreadsheets']

    # Connect to database
    creds = None
    # The file token.json stores the user's access and refresh tokens, and is
    # created automatically when the authorization flow completes for the first
    # time.
    if os.path.exists('token.json'):
        creds = Credentials.from_authorized_user_file('token.json', SCOPES)
    # If there are no (valid) credentials available, let the user log in.
    if not creds or not creds.valid:
        if creds and creds.expired and creds.refresh_token:
            creds.refresh(Request())
        else:
            flow = InstalledAppFlow.from_client_secrets_file(
                credentials, SCOPES)
            creds = flow.run_local_server(port=0)
        # Save the credentials for the next run
        with open('token.json', 'w') as token:
            token.write(creds.to_json())

    return creds

# %%
credential = connect_sheet("./archive/credentials.json")
credential

# %%
# CONSEGUIR DATOS DE BASE DE DATOS
def get_data(creds):

    # The ID and range of a sample spreadsheet.
    SAMPLE_SPREADSHEET_ID = '1Ge_nrrNF9VoVMysRiGm-Is53jSMh2OL_8cxTIimfpxE'
    bd_cotizaciones = 'BD_Cotizaciones_de_proveedores!A1:Q'
    planilla = 'Planilla!A1:G'

    # Call the Sheets API
    service = build('sheets', 'v4', credentials=creds) 
    sheet = service.spreadsheets()

    # Get data from database
    bd_cotizaciones_data = sheet.values().get(spreadsheetId=SAMPLE_SPREADSHEET_ID,
                                range=bd_cotizaciones).execute()
    bd_cotizaciones_data_values = bd_cotizaciones_data.get("values",[])

    planilla_data = sheet.values().get(spreadsheetId=SAMPLE_SPREADSHEET_ID,
                                range=planilla).execute()
    planilla_data_values = planilla_data.get("values",[])

    # Save as pandas dataframe
    df_bd = pd.DataFrame.from_records(bd_cotizaciones_data_values[1:],columns=bd_cotizaciones_data_values[0])
    df_planilla = pd.DataFrame.from_records(planilla_data_values[1:],columns=planilla_data_values[0])
    df_bd.to_csv("./data/productos_cotizados.csv", index=False)

    return df_bd, df_planilla

# %%
df_productos, df_planilla = get_data(credential)
df_productos
# Out:
#             Cotizacion Producto Solicitado  \
# 0     47630ddf50e6f0e4            5a76b72b
# 1     47630ddf50e6f0e4            3d56f01b
# 2     47630ddfb5351092            3d56f01b
# 3     47630ddf05708cfd            3d56f01b
# 4     47630ddf05708cfd            5a76b72b
# ...                ...                 ...
# 8373          3907425d            d97a6a43
# 8374          20a4f2e8            d97a6a43
# 8375          a7534af2            05cf810c
# 8376          dd86b2dd            d89f9fcf
# 8377          f423d828            4df33ed5
#
#                                       Producto Ofrecido U. Medida Cantidad  \
# 0     MONITOR LG 21.5’’ (22MN430M-B), 1920 X 1080 (F...    Unidad        2
# 1     TECLADO INALAMBRICO  + MOUSE INALAMBRICO GENIU...    Unidad       15
# 2     TECLADO INALAMBRICO  + MOUSE INALAMBRICO TEROS...    Unidad       15
# 3     COMBO LOGITECH: TECLADO + MOUSE MK220 WIRELESS...    Unidad       15
# 4     MONITOR 22” SAMSUNG LF22T350FHLXPE iPS FHD HDM...    Unidad        2
# ...                                                 ...       ...      ...
# 8373  Cámara Canon Powershot SX 70 HS.\nIncluye:\n(0...    Unidad        2
# 8374  Cámara digital Canon PowerShot SX70 HS\nConten...    Unidad        2
# 8375  CONDUCTOR ELECTRICO 1KV LIBRE HALOGENO 4MM2 NE...     Metro       30
# 8376         ETIQUETA INKJET A4 003  PEGAFAN X 50 HOJAS   Paquete       10
# 8377  Pro-Line Diesel System cleaner / Limpiador de ...    Unidad        1
#
#      Costo x Unidad Costo x Unidad SIN IGV en Soles Precio Venta x Unidad  \
# 0             550.5                          466.53                601.17
# 1              78.4                           66.44                  82.1
# 2              59.9                           50.76                  82.1
# 3              77.5                            77.5                  82.1
# 4             567.5                           567.5                601.17
# ...             ...                             ...                   ...
# 8373           2999                       2541.5254                  2997
# 8374           3199                       2711.0169                  3197
# 8375            4.5                             4.5                   7.5
# 8376           32.3                         27.3729                     0
# 8377            300                        254.2373                   349
#
#                                                    Link  \
# 0
# 1
# 2     https://dasmitec.pe/productos/kit-inalambrico-...
# 3     https://www.memorykings.com.pe/producto/327993...
# 4
# ...                                                 ...
# 8373  https://store.lenz.pe/products/camara-canon-po...
# 8374  https://filmadorasperu.com/products/camara-dig...
# 8375
# 8376
# 8377
#
#                         Observaciones Habilitar y Deshabilitar  \
# 0                                                Deshabilitado
# 1                                                Deshabilitado
# 2                                                Deshabilitado
# 3                                                Deshabilitado
# 4                                                   Habilitado
# ...                               ...                      ...
# 8373                                                Habilitado
# 8374                                                Habilitado
# 8375                                                Habilitado
# 8376  ** comprar rapido pq se acaba**               Habilitado
# 8377                                                Habilitado
#
#                                           Adjunto Adjunto Ficha Tecnica  \
# 0
# 1
# 2
# 3
# 4
# ...                                           ...                   ...
# 8373
# 8374
# 8375  Files/R2023-545/4f27df00.Adjunto.222940.pdf
# 8376
# 8377  Files/R2023-561/8d9898bf.Adjunto.224937.jpg
#
#                                      Imagen Referencial Ultima revisión  \
# 0
# 1
# 2
# 3
# 4
# ...                                                 ...             ...
# 8373  Files/R2023-559/7a1fcc0c.Imagen Referencial.22...
# 8374  Files/R2023-559/ef0b4113.Imagen Referencial.22...
# 8375
# 8376
# 8377
#
#          TRAZA OC a proveedor
# 0     152e43f1           None
# 1     1ac5849a           None
# 2     d79583f9           None
# 3     aedc03a3           None
# 4     398d553b           None
# ...        ...            ...
# 8373  7a1fcc0c           None
# 8374  ef0b4113           None
# 8375  4f27df00           None
# 8376  2495bc2c           None
# 8377  8d9898bf           None
#
# [8378 rows x 17 columns]

# %%
df_planilla
# Out:
#        Cod Req    Categoria  \
# 0     47630ddf      Cómputo
# 1     47630ddf      Cómputo
# 2     47630ddf      Cómputo
# 3     47630ddf      Cómputo
# 4     cff1de24       Sillas
# ...        ...          ...
# 5068  4c2bcf9f  Misceláneos
# 5069  8b85c977   Eléctricos
# 5070  8b85c977  Misceláneos
# 5071  8b85c977  Misceláneos
# 5072  6129d3b9  Misceláneos
#
#                                     Producto Solicitado U. Medida Cantidad  \
# 0                          SOPORTE PARA LAPTOP 3M LX550    Unidad        0
# 1              TECLADO INALAMBRICO  + MOUSE INALAMBRICO    Unidad        0
# 2                                           MONITOR 22”    Unidad        0
# 3                                  SOPORTE PARA MONITOR    Unidad        7
# 4                                     Sillas ejecutivas    Unidad        9
# ...                                                 ...       ...      ...
# 5068                     Cámara CANON PowerShot SX70 HS    Unidad        2
# 5069  ESTUFA ELÉCTRICA DE ACEITE SOLE 1500W modelo 3...    Unidad        2
# 5070                            ACEITE SINTÉTICO LE32H1     Galón        2
# 5071         ETIQUETA INKJET A4 003  PEGAFAN X 50 HOJAS   Paquete       10
# 5072  Pro-Line Diesel System cleaner / Limpiador de ...    Unidad        1
#
#      Observaciones     TRAZA
# 0                   553486da
# 1                   3d56f01b
# 2                   5a76b72b
# 3                   881845a2
# 4                   d5c875c4
# ...            ...       ...
# 5068                d97a6a43
# 5069                b3c450f7
# 5070                029ba295
# 5071                d89f9fcf
# 5072                4df33ed5
#
# [5073 rows x 7 columns]

# %%
# NORMALIZAR NOMBRES
def normalize(df,columna_producto):
    new_column ="Norm_" + columna_producto 
    df[new_column] = [clean_text(producto,True,True,True) for producto in df[columna_producto]]

    return df

# %%
df_productos = normalize(df_productos,"Producto Ofrecido")
df_productos
# Out:
#             Cotizacion Producto Solicitado  \
# 0     47630ddf50e6f0e4            5a76b72b
# 1     47630ddf50e6f0e4            3d56f01b
# 2     47630ddfb5351092            3d56f01b
# 3     47630ddf05708cfd            3d56f01b
# 4     47630ddf05708cfd            5a76b72b
# ...                ...                 ...
# 8373          3907425d            d97a6a43
# 8374          20a4f2e8            d97a6a43
# 8375          a7534af2            05cf810c
# 8376          dd86b2dd            d89f9fcf
# 8377          f423d828            4df33ed5
#
#                                       Producto Ofrecido U. Medida Cantidad  \
# 0     MONITOR LG 21.5’’ (22MN430M-B), 1920 X 1080 (F...    Unidad        2
# 1     TECLADO INALAMBRICO  + MOUSE INALAMBRICO GENIU...    Unidad       15
# 2     TECLADO INALAMBRICO  + MOUSE INALAMBRICO TEROS...    Unidad       15
# 3     COMBO LOGITECH: TECLADO + MOUSE MK220 WIRELESS...    Unidad       15
# 4     MONITOR 22” SAMSUNG LF22T350FHLXPE iPS FHD HDM...    Unidad        2
# ...                                                 ...       ...      ...
# 8373  Cámara Canon Powershot SX 70 HS.\nIncluye:\n(0...    Unidad        2
# 8374  Cámara digital Canon PowerShot SX70 HS\nConten...    Unidad        2
# 8375  CONDUCTOR ELECTRICO 1KV LIBRE HALOGENO 4MM2 NE...     Metro       30
# 8376         ETIQUETA INKJET A4 003  PEGAFAN X 50 HOJAS   Paquete       10
# 8377  Pro-Line Diesel System cleaner / Limpiador de ...    Unidad        1
#
#      Costo x Unidad Costo x Unidad SIN IGV en Soles Precio Venta x Unidad  \
# 0             550.5                          466.53                601.17
# 1              78.4                           66.44                  82.1
# 2              59.9                           50.76                  82.1
# 3              77.5                            77.5                  82.1
# 4             567.5                           567.5                601.17
# ...             ...                             ...                   ...
# 8373           2999                       2541.5254                  2997
# 8374           3199                       2711.0169                  3197
# 8375            4.5                             4.5                   7.5
# 8376           32.3                         27.3729                     0
# 8377            300                        254.2373                   349
#
#                                                    Link  \
# 0
# 1
# 2     https://dasmitec.pe/productos/kit-inalambrico-...
# 3     https://www.memorykings.com.pe/producto/327993...
# 4
# ...                                                 ...
# 8373  https://store.lenz.pe/products/camara-canon-po...
# 8374  https://filmadorasperu.com/products/camara-dig...
# 8375
# 8376
# 8377
#
#                         Observaciones Habilitar y Deshabilitar  \
# 0                                                Deshabilitado
# 1                                                Deshabilitado
# 2                                                Deshabilitado
# 3                                                Deshabilitado
# 4                                                   Habilitado
# ...                               ...                      ...
# 8373                                                Habilitado
# 8374                                                Habilitado
# 8375                                                Habilitado
# 8376  ** comprar rapido pq se acaba**               Habilitado
# 8377                                                Habilitado
#
#                                           Adjunto Adjunto Ficha Tecnica  \
# 0
# 1
# 2
# 3
# 4
# ...                                           ...                   ...
# 8373
# 8374
# 8375  Files/R2023-545/4f27df00.Adjunto.222940.pdf
# 8376
# 8377  Files/R2023-561/8d9898bf.Adjunto.224937.jpg
#
#                                      Imagen Referencial Ultima revisión  \
# 0
# 1
# 2
# 3
# 4
# ...                                                 ...             ...
# 8373  Files/R2023-559/7a1fcc0c.Imagen Referencial.22...
# 8374  Files/R2023-559/ef0b4113.Imagen Referencial.22...
# 8375
# 8376
# 8377
#
#          TRAZA OC a proveedor  \
# 0     152e43f1           None
# 1     1ac5849a           None
# 2     d79583f9           None
# 3     aedc03a3           None
# 4     398d553b           None
# ...        ...            ...
# 8373  7a1fcc0c           None
# 8374  ef0b4113           None
# 8375  4f27df00           None
# 8376  2495bc2c           None
# 8377  8d9898bf           None
#
#                                  Norm_Producto Ofrecido
# 0     monitor lg 21 5 22mn430m b 1920 1080 fhd ips 2...
# 1     teclado inalambrico mouse inalambrico genius k...
# 2     teclado inalambrico mouse inalambrico teros 40...
# 3     combo logitech teclado mouse mk220 wireless us...
# 4     monitor 22 samsung lf22t350fhlxpe ips fhd hdmi vg
# ...                                                 ...
# 8373  camara canon powershot sx 70 hs incluye 01 mem...
# 8374  camara digital canon powershot sx70 hscontenid...
# 8375  conductor electrico 1kv libre halogeno 4mm2 ne...
# 8376            etiqueta inkjet a4 003 pegafan 50 hojas
# 8377  pro line diesel system cleaner limpiador inyec...
#
# [8378 rows x 18 columns]

# %%
df_planilla = normalize(df_planilla,"Categoria")
df_planilla = normalize(df_planilla,"Producto Solicitado")
df_planilla
# Out:
#        Cod Req    Categoria  \
# 0     47630ddf      Cómputo
# 1     47630ddf      Cómputo
# 2     47630ddf      Cómputo
# 3     47630ddf      Cómputo
# 4     cff1de24       Sillas
# ...        ...          ...
# 5068  4c2bcf9f  Misceláneos
# 5069  8b85c977   Eléctricos
# 5070  8b85c977  Misceláneos
# 5071  8b85c977  Misceláneos
# 5072  6129d3b9  Misceláneos
#
#                                     Producto Solicitado U. Medida Cantidad  \
# 0                          SOPORTE PARA LAPTOP 3M LX550    Unidad        0
# 1              TECLADO INALAMBRICO  + MOUSE INALAMBRICO    Unidad        0
# 2                                           MONITOR 22”    Unidad        0
# 3                                  SOPORTE PARA MONITOR    Unidad        7
# 4                                     Sillas ejecutivas    Unidad        9
# ...                                                 ...       ...      ...
# 5068                     Cámara CANON PowerShot SX70 HS    Unidad        2
# 5069  ESTUFA ELÉCTRICA DE ACEITE SOLE 1500W modelo 3...    Unidad        2
# 5070                            ACEITE SINTÉTICO LE32H1     Galón        2
# 5071         ETIQUETA INKJET A4 003  PEGAFAN X 50 HOJAS   Paquete       10
# 5072  Pro-Line Diesel System cleaner / Limpiador de ...    Unidad        1
#
#      Observaciones     TRAZA Norm_Categoria  \
# 0                   553486da        computo
# 1                   3d56f01b        computo
# 2                   5a76b72b        computo
# 3                   881845a2        computo
# 4                   d5c875c4         sillas
# ...            ...       ...            ...
# 5068                d97a6a43    miscelaneos
# 5069                b3c450f7     electricos
# 5070                029ba295    miscelaneos
# 5071                d89f9fcf    miscelaneos
# 5072                4df33ed5    miscelaneos
#
#                                Norm_Producto Solicitado
# 0                               soporte laptop 3m lx550
# 1                 teclado inalambrico mouse inalambrico
# 2                                            monitor 22
# 3                                       soporte monitor
# 4                                     sillas ejecutivas
# ...                                                 ...
# 5068                     camara canon powershot sx70 hs
# 5069  estufa electrica aceite sole 1500w modelo 3120...
# 5070                            aceite sintetico le32h1
# 5071            etiqueta inkjet a4 003 pegafan 50 hojas
# 5072  pro line diesel system cleaner limpiador inyec...
#
# [5073 rows x 9 columns]

# %%
# COMBINAR NOMBRES DFs
def combinar_bd(df1,df2,column1,column2):
    """
    Combines two pandas DFs

    ** df1 = pandas DF al que añadir valores
    ** df2 = pandas DF del que se sacaran valores
    ** column1,2 = Str. Nombre de la columna con el idx de connecion

    Lista a conseguir
    # Producto solicitado
    # Producto ofrecido
    # Categorias
    # Producto solicitado con categorias
    # Producto ofrecido con categorias
    # Producto solicitado con categoria y todos los prod ofrecidos
    """
    # Combinar dfs
    df = pd.merge(df1, df2,
                       how='left', left_on=column1, right_on=column2)
    
    # Make TRAIN_DATA
    TRAIN_DATA = []
    # Producto solicitado
    TRAIN_DATA = TRAIN_DATA + df["Norm_Producto Solicitado"].values.tolist() 
    # Producto ofrecido
    TRAIN_DATA = TRAIN_DATA + df["Norm_Producto Ofrecido"].values.tolist() 
    # Categorias
    TRAIN_DATA = TRAIN_DATA + df["Norm_Categoria"].values.tolist() 
    # Producto solicitado con categorias
    df["sol_categoria"] = df["Norm_Producto Solicitado"]+ " "+ df["Norm_Categoria"]
    TRAIN_DATA = TRAIN_DATA + df["sol_categoria"].values.tolist() 
    # Producto ofrecido con categorias
    df["ofr_categoria"] = df["Norm_Producto Ofrecido"]+ " "+ df["Norm_Categoria"]
    TRAIN_DATA = TRAIN_DATA + df["ofr_categoria"].values.tolist() 
    # Producto solicitado con categoria y todos los prod ofrecidos
    df["todo"] = df["Norm_Producto Solicitado"]+ " " + df["Norm_Categoria"] + " " +df["Norm_Producto Ofrecido"]
    TRAIN_DATA = TRAIN_DATA + df["todo"].values.tolist()  

    # Remove duplicates
    TRAIN_DATA = list(set(TRAIN_DATA))
    
    return TRAIN_DATA

# %%
TRAIN_DATA = combinar_bd(df_productos,df_planilla,"Producto Solicitado","TRAZA")
TRAIN_DATA
# Out:
# [nan,
#  '',
#  'balanza electronica altura peso 300kg 100g mantenimiento balanza electronica altura peso 300kg 100g',
#  'hojas cartulina kimberly a4 220 grs blanco titanio',
#  'ocion 2 hervidor oster 1 7 l blanco garantia 1 ano 2 dias cafeteria',
#  'tacho vaiven color negro residuos generales 60 l limpieza tacho cosmos color negro residuos generales 60 l rey plast 2 dias',
#  'papelera automatica clin metalizada 12 5l rey plasticos',
#  'vela misionera 6',
#  'escalera plataforma 8 peldanos raptor',
#  'pano microfibra virutex 4 limpieza',
#  'rack tv fijo inclinable 26 65 krearack negroinclinacion 15o',
#  'televisor samsung led 50 uhd 4k smart tv un50au7090gxpe',
#  '54 cera agua tekno 1 gl',
#  'escalera telescopica 20 pasos',
#  'caja 33cm 58 5cm 21cm 3 4 kg',
#  '12 jabon liquido rosas galon daryza limpieza',
#  'embudo aceite cuello flexible 2 gal',
#  'esponja azul scotch brite paquete 6',
#  'lavavajilla liquida sapolio galon 5 lt ',
#  'limpiador polvo sapolio antibacterial azul frasco 450g limpieza pulidor polvo sapolio frasco 450 gr bano azul',
#  'cubrecalzado seguridad cubrecalzado seguridad visitor punta aluminio titanio tiger grip seguridad indutrial',
#  'jabon liquido aval antibacterial sachet 800 ml frutos rojos limpieza',
#  'junta universal 1 2 j5470a proto mantenimiento',
#  'pqt bolsas basura 18 l negras 100 limpieza',
#  'sillas giratorias lyon negro sillas',
#  'camara hero10 black gopro electricos camara accion hero10 gopro black procesador gp2 captura fotos 23 mp videos 5 3k resistente sumergible 10 m compatible aplicacion quik estabilizacion vadeo avanzada hypersmooth 4 0',
#  'caja china fabricado acero inox 304 espesor 1 2 mm medidas 1 60 40 80 patas tubulares inox parrilla grill superior acero inox miscelaneos caja china fabricado acero inox 304 espesor 1 2 mm medidas 1 60 40 80 patas tubulares inox parrilla grill superior acero inox imagen referencial',
#  'protector cable caucho sbr 4 canales dimensiones longitud 930 mm ancho 500 mm altura 50 mm',
#  'camara fotografica resistentes agua polvo electricos camara digital panasonic dmcsdfz300k tarj est 12 1mp',
#  '33 barras acero corrugado diametro 3 4pulg grado 60 longitud 9m herramietas',
#  'dado impacto tubular 20mm enc 1 2 6pt proto j7320m mantenimiento',
#  'potassium ferrocyanide c s p236 frasco 500 g cas14459 95 1 quimicos',
#  'llave torx l pavonada t9 1995torx t9 bahco',
#  'caja organizadora movil suprema 80 57 9 l sku 114855 colores aleatorios caja plastica',
#  'bandejas mar peruano cerrada azul 40l 69 6 ancho 41 0 altura 24 0 cm 5 mm capacidad 25kg 40l',
#  'escritorio 110 53 76 cm muebles escritorio cajonera movil fabricado melamina 18mm medidas 110cm 53cm 76cm alto bordes contaran tapacantos grueso pvc anti impacto 3 0 45mm espesor adherido termofusion maquina ensamble realizara tornillos spax cubre tornillos autoadhesivos color melamina cajonera 3 gavetas fabricado melamina 18mm cajones sistema correderas telescopicas larga extraccion permite acceso interior cajon billas aceradas cincadas capacidad carga 25 k aprox posee freno retencion evitar aperturas involuntarias cerradura multiple frontal cajones posee 2 llaves doble perfil cubierta plastica negra tambor acerado sistema interno aluminio retenes sujetadores sincalados opcional tiradores acero inoxidables sujetos tornillos estoboles autoroscantes deslizadores pvc contacto',
#  'veladores dormitorio c cajones modelo cajones medidas 50cm alto 40cm 35cm fondo',
#  'televisor samsung smart televisor 70 uhd 4k un70au7000gxpe 02 dias televisor',
#  '1 camilla pvc 1 177 97 177 97 1 inmovilizador 1 130 16 130 16 3 extintor 6 kilos 1 70 00 70 00 4 ferulas rigidas 1 48 00 48 00 5 collarin 1 55 00 55 00 6 botiquin descartable 1 23 00 23 00 7 ferulas neumaticas 1 240 00 240 00 8 caseta madera tryplay 4mm 1m 1m 2m color rojo letras color amarillo kit emergencia 1 850',
#  'lejia sapolio galon limpieza lejia sapolio 5 litros',
#  'cortina p bano 1 50mt 1 80 mts vinyl c argollas nacional',
#  'detector tormeta storm pro 2 bateria 9 v cargador 9x16x5cm',
#  'bidon aceitunero capacidad 60l',
#  '74 40 hb38 kd rd abus candado dielectrico 1 5 rojo bloqueo',
#  'limpiador acero inoxidable spray 21 onz 3m limpieza limpiador acero inoxidable spray 21 onz 3m',
#  'estuche pana acuerdo medidas trofeo miscelaneos',
#  'caja portallaves puerta vidrio 40cm alto 30 cm ancho 15 cm prof modelo enviado',
#  'abus candado dielectrico 1 5 rojo',
#  'escalera fv 3 pasos 1acceso louisville fs1403hd tipo iaa escaleras escalera 4 pasos tardecraft',
#  'utiles limpieza limpieza utiles limpieza',
#  '34 pintura spray negro mate shurtape',
#  'pegafan cinta doble faz 1 11 yd',
#  'lapicero azul bps gp f 0 7 mm pilot tinta',
#  'dado estandar 3 8dr 9 16 6pt proto j5218h entrega 3 4 meses mantenimiento',
#  'caja 17 22 14 5 cm empaques embalajes',
#  'impresora epson l3150 wifi oficina impresora multifucional epson ecotank l3250 wifi imprime copia escanea',
#  'llave combinada 7mm mod 1952m 17s mc bahco',
#  'dispensador stretch film miscelaneos dispensador stretch film 12 20 regulable',
#  '44 manguera extensible 15m pistola verde',
#  'manta polar sherpa 1 plaza medida 90cmx 190 200cm miscelaneos manta sherpa medidas 2 metros ancho 1 5 metros',
#  'panuelo facial kleenex dia dia 80un kleenex referencia 176788 limpieza panuelo facial kleenex dia dia 80un',
#  'barniz spray aislante 1601 transparente 3m miscelaneos barniz spray aislante 1601 transparente',
#  'agua mineral gas san mateo 600 ml cafeteria agua mineral gas san mateo 600 ml',
#  '1 martillo mango fibra vidrio 20 onz herramietas',
#  'cinta vinilo ancho 1 pulg verde p rotulador brady bmp71 miscelaneos',
#  'cascos seguridad amarillos 3m h 702 sistema ratchet',
#  'altaernativa gaveta plastica azul ndeg 6 295 217 ancho 174 alto 147',
#  'servicio tapizado ensamblaje tela negra sillas',
#  'maquina enzunchadora p zuncho metalico tenaza tenzador mantenimiento',
#  '66 dun dun mortero polimerico 3 kg herramietas 66 dun dun mortero polimerico 3 kg',
#  'ganchos funda pvc',
#  'gasa est 5x5x 5 cajax20alk fv 2024',
#  'bandejas geomembranas 1m 1m 20 cm mantenimiento',
#  'espatula flexible 3 cod 14449 truper herramientas',
#  'strech film transparente 15 20 micras solpack empaques embalajes',
#  'lima aguja diam media cana 5 5x1 6mm df4152 d126 016924 mantenimiento lima aguja diam media cana 5x 1 7mm 140mm s m 2 304 14 d 1p bahco',
#  'pote 1 lt t 63 blanco plasticos',
#  'resaltador textliner 48 amarillo f castell oficina resaltador textliner 48 amarillo f castell',
#  'cuchillo p electricista recto 1000v bahco 2820 vp 2820vde',
#  'solvente dielectrico ecologico ss 25 nc x1gln chemsearch',
#  'arnes soldador kevlar msa protecta 3m seguridad indutrial arnes gravity welder soldador 4 anillos talla std',
#  'caja 12 plumon jumbo negro indeleble ndeg 23 faber castell oficina',
#  'escritorio l ancho 170 150 alto 74 prof 53cm muebles escritorio melamine 18mm espesor canto grueso termofundido anti impactos 3mm espesor cajonera fija 3mm espesor color wengue medidas 1 50l 1 71 0 75',
#  'torquimetro golpe mod 6448 3 4 163 813nm 120 600lb pie wrighttool',
#  'adaptador pvc agua 4 iny mantenimiento',
#  'sillas escritorio rudy alta',
#  'soporte laptop logo computo',
#  'plumon pizarra alpha 123 negro',
#  'interruptor simple domino sencia blanco bticino seguridad indutrial interruptor simple domino sencia blanco ticino',
#  'cobertores silicona zapatos miscelaneos',
#  'mota pizarra acrilica artesco color azul pano industrial anti polvo antipolilla oficina mota p pizarra eco artesco',
#  'cajas clips metalicos artesco 100 oficina cajas clips metalicos artesco 100',
#  'cinta ducto rojo cinta adhesiva duct tape reparacion 3m rojo 1 88 in 20 yd',
#  'sapolio lavavajilla liquido limon 750 ml',
#  'thule maletin gauntlet 3 0 attache 15 oficina',
#  'dispensador alcohol pared',
#  'cocina induccion nationalizer 2400 wci 2167 miscelaneos cocina induccion nationalizer 2400 watts tecnologia aleman',
#  'galleta club social 6',
#  'crimpeadora rj45 electricos crimpeadora rj45 trendnet',
#  'pila a2 duracell 4 oficina pila a2 duracell 4',
#  'buzo desechable naranja talla l seguridad indutrial buzo desechable color blanco talla l',
#  'pinza hielo krea medidas long anch alt 8 16 2 cm limpieza',
#  'tuerca hex grado 8 unc 3 8',
#  'tubo led 4 pines 26w 840 philips electricos',
#  'edredon polialgodon fibra 120 gr 1 1 2 plaza blanco',
#  'impresora epson l3250 ecotank epson',
#  'raid zancudos moscas 400 ml raid mata cucarachas chiripas limpieza',
#  'maquina humo 1500w soporte montaje 2 remoto pur newark1500 lightreferencia sa50677a pur light miscelaneos',
#  'insecticidas spray limpieza insecticida spray mata 360 ml',
#  'portallaves adhesivo blanco miscelaneos portallaves adhesivo blanco',
#  'repuesto trapeador microfibra mopa plana virutex limpieza',
#  'tacho 22 lt color azul limpieza tacho vaiven n20 genplast alto 47 6 cm 28 7 cm ancho 23 9 cm capacidad 20 litros disponibilidad inmediata',
#  'protector almohada',
#  'focos led 15 w luz calida tipo rosca e27 alto 11 8 cm ancho 6 cm mantenimiento',
#  'displey esponja doble scotch brite 7 limpieza',
#  'caja papel filtro whatman grado 40',
#  'tomacorriente domestico empotrado mantenimiento tomacorriente doble universal tierra domino sencia blanco bticino',
#  'hervidor electrico 1 7 l 2 l garantia cafeteria hervidor electrico thomas 1 8 l th4330 garantia 1 ano 2 dias',
#  'pinza amperimetrica digital fluke 1000a 1000vac dc modelo 376 frasco mantenimiento pinza amperimetrica ac dc true rms 1000a center',
#  'alcohol gel fiorucchi galon',
#  'papelera rectangular 30 letars',
#  '3100084457 cinta rotuladora brother oficina cinta laminada brother tze231 texto negro fondo blanco 12 mm 8 m compatible pth110bk',
#  'juego 2 baterias ion litio 18v lxt 6 0ah makita bl1860b ref632f69 8',
#  'colchones plaza media miscelaneos colchon singles ultra 1 5 plazamaterial acolchado tela tricot',
#  'carga factura usd gastos exw pick up 1 2 dias aprox usd 1 260 00 air freight usd 4 820 00 poliza seguro internacional usd cif usd 6 080 00 gastos destino igv handling g servicio comercio exterior usd usd 92 00 60 00 usd 16 56 servicio usd 6 248 56',
#  'telefono inalambrico motorola auri 2020 negro 12 meses garantia 2 dias electricos',
#  'llave hexagonal pavonada torx t20 1995torx t20 bahco codigo be 8675 corresponde llaves juego cotiza codigo individual ft adjunta',
#  'cinta masking tape azul scotch blue 48 mm 54 8 m',
#  'barniz rojo tipo h',
#  'dremel grabador 35w electrico modelo dremel 290 mantenimiento',
#  'cargador pilas camelion aa aaa 4 pilas aaa 1100 mah',
#  'hd utility cart 2 shelf 24 36 codigo fg452088bla carro servicio 2 repisas resistente espuma estructural oxida abolla descascara compartimientos estandar repisa superior guardar sostener vasos esquinas redondeadas peso liviano maniobrable ruedas 5 diametro dejan marcas 2 fijas 2 giratorias capacidad 227 kg medida 114 9 cm 65 7 cm 84 5 cm garantia ano defectos fabrica disponible resto importar estimado llegada 120 dias aprox mantenimiento',
#  'rele cod hf42f 005 2hs 24vdc 5a 250vac 5a 30vdc mantenimiento rele hf42f 005 2hs bobina 5vdc carga 5a 250vac 5a 30vdc',
#  'rastrillo jardinero 16 dientes mango pino 54 cabeza 16 espesor 1 4 arco 5 16 r 16am 17882 truper mantenimiento',
#  'azucar rubia bolsa 1 kg limpieza dulfina azucar rubia 1 kg',
#  'alicate punta 6 larga kamasa miscelaneos',
#  'jabon antibacterial avena barra 110 g pack 3 protex limpieza jabon antibacterial protex avena pack 3 x110gr',
#  'cuchilla recta dielectrica guarda seguridad herramientas cuchilla electricista aislada 1000v hoja cubierta',
#  'horno microondas samsung 23l ms23j5133am pe negro electricos',
#  'llave sacar filtro acete lona 4 9 proto jff278 mantenimiento llave sacar filtro aceite lona 6 stanley 78 230',
#  'palet plastico hdpe modelo fortex capacidad carga estatica 2500kg carga estatica 4 ton cap carga diamica 1 3 ton apilacion piso dimensiones 1m 1 2 mx 15cm miscelaneos',
#  'pallets plastico medidas estandar 1m 1 2m',
#  'persiana horizontal pvc angora 100x165cm',
#  'rack televisor 75 pulgadas movil 2 brazos color negro plomo tacto cuero mate placas metal aceros arequipa',
#  'marcador neumatico metales dremel incluir puntas grabar',
#  'tachos residuos solidos 120l capacidad tapa ruedas pedal apertura logo',
#  'perforador metalico u 20 20 hojas rojo negro azul oficina',
#  'kit decorar galletas miscelaneos',
#  'candado brady master lock rojo 1 77 x1 5',
#  'recogedor plastico hude limpieza',
#  'mica pantalla laptop lenovo computo protector mica pantalla laptop 14',
#  'engrapadora 25h m 526 negro artesco oficina',
#  'escalera dielec plataf fibra vidrio136kg 4 pasos amarillo ansi asc a14 5 ruedas accesomarca horn modelo hesc fv604 equipos',
#  'maiz molido fino nacional quimicos 4 maiz molido fino nacional sacos 60 kg',
#  'kit antiderrame 20l tipo oleofilico hidrofobico hidrocarburos cap absorcion 20 l maletin 50x30x20cm incluye panos absorcion cordon abs oleofilico traje descartable guantes nitrilo lent seguridad respirador descartable bolsa roja alimentacion cintillos cierre bolsas eliminacion instructivo maletin contencion mantenimiento',
#  'comba cobre berilio 4 libras mantenimiento comba cobre berilio 4 libras mando fibra vidrio farmesa',
#  'tacho madera clasico',
#  'abrebidones manual efecto palanca mantenimiento descabezador tambor actualizado empunadura plastico tambores acero hojas aleacion cobre producen chispas',
#  'comba cobre berilio 25 libras mando fibra vidrio farmesa',
#  'parihuela plastica carga estatica maxima 6000 kg',
#  'perfumador induster aroma fresa 3 8l limpieza',
#  'lubricante multiusos wd 40 11 onzas mantenimiento lubricante multiusos wd 40 11 onzas',
#  '1 cemento sol portland tipo i bolsa 42 5 kilogramo herramientas',
#  'forro adhesivo transparente 0 45 3 mt artesco oficina forro adhesivo 45cm 3mt artesco film',
#  'pallets 1 20 1 00 m c tratamiento termico exportacion empaques embalajes parihuela madera 1 20 mts 1 00 mts incluye t termico',
#  'car600w inversor adaptador voltaje energit',
#  'tecle cadena 5 tonelada mantenimiento tecle manual cadena 5 toneladas jvl certificado grado cadena g80',
#  'escalera tipo tijera 10 peldanos escaleras escalera dielec t tijera doble acc fib vidrio170kg 10 pasos colores disponibles amarillo rojo naranja',
#  'pulverizador presion 2 l miscelaneos',
#  'balde reyplast 11 lt c pico verde',
#  'audifonos plegables negro sony mdr zx310apbcuc electricos',
#  'tazas desayuno',
#  'alfombra felpudo pvc atrapa mugre 40 cm 60 cm 1 cm gris limpieza felpudo atrapa mugre pvc transito gris medidas 60 40cm 1 0 cm',
#  'opcion 2 10057501 cucharita modelo 60 facusa docena cafeteria',
#  'bolsa jabon liquido dispensador 500ml ebriel',
#  '99552 brady candado seguridad 1 5 rojo',
#  'arnes 3 anillas 3 hebillas hauk',
#  'espatulas',
#  'brochas latex 1 1 2 material cerdas poliester material mango madera tumi',
#  'papel higienico pequeno 24 elite limpieza papel higienico pequeno 24 elite',
#  'goniometro digital insize 2171 250',
#  'lector optico okk usb emh miscelaneos',
#  'saca grapas',
#  'botador 2mm mod 3734 s 6 mc bahco mantenimiento',
#  'caja metalica roja bandeja pieza',
#  'hidrolavadora inalambrica dhw080pt2 18vx2 makita incluye 1 cargador doble 2 baterias 5 ah 2 dias',
#  'lampara matainsectos modelo eg05 2x15w corriente continua 220v 60hz lampara atraccion 15w consumo 20w cobertura 100 mt2 medidas 55 3 7 8 28 7 cm peso 3 9 kg viene 2 laminas adhesivas eg05 2x15w',
#  'manguera oxicorte 30 metros lona jebe mantenimiento manguera melliza parker 1 4',
#  'llave mixta 23 mm 86 868 stanley mantenimiento',
#  'cartulinas colores pastel foto pliego oficina cartulina plastificada pliegos color lila 2 pliego',
#  'llave t 10 mm wiseup mantenimiento llave tipo t 10mm tool tech taiwanes acero cromo vanadio',
#  'caja metalica roja 26 8 3 4 9 williams mantenimiento',
#  'cinta aislante negra pieza mantenimiento',
#  'secador botas miscelaneos secador botas',
#  'lapiz artesco 2b grafito c borrador cjx12 oficina',
#  'talco 600 gr miscelaneos talco bebe johnson s baby frasco 600 g',
#  'lavavajilla liquido ayudin limon sabila botella 1 4l',
#  'carro zuncho metalico mantenimiento',
#  'telwinarrancador cargador probador bateria multifuncional startzilla 3024 tecnologia telwin mantenimiento',
#  'tarjeta mensaje alusivo merchandising',
#  'dispensador vasos miscelaneos dispensador vasos dramox',
#  'azucarera blanca 9 9 11 cm',
#  'balaclava hardwork wind negro impermeable seguridad indutrial balaclava hardwork wind negro impermeable',
#  'bolsa basura 75 litros pqtx 10 limpieza bolsas basura home care 75 litros contenido 10',
#  'juego cortafrios ref 3736s 6 mc bahco mantenimiento jgo buriles cortafrios 6p 3736s 6 bahco',
#  'reduccion pvc sp 1 1 2 1 2 pulg p agua pavco mantenimiento reduccion pvc sp 1 1 2 1 2 pulg p agua termoformado tubo pavco',
#  'silla gerencial rta 317b bs',
#  'garrucha pesada giratoriacon freno poliuretano 4',
#  'interruptor conmutacion empotrado',
#  'jg llaves combinacion mm satin 7 24mm 18 pz 12 pt proto j1200r masd',
#  'pistola impacto neumatica 3 4 pulg sugerida proto mantenimiento pistola impacto neumatica 3 4 truper',
#  'caja organizadora luxor 12l plasticos caja luxor 12l',
#  'zuncho poliester 5 8',
#  'bateria lipo 2s 7 4v 3000 mah recargable',
#  'impresora epson l3150 wifi oficina impresora epson l3250 ecotank epson',
#  'portaherramientas stanley fatmax fmst20061',
#  'kit ropa anti arco indura 26 8cal cm2 talla xl talla s seguridad indutrial kit ropa anti arco indura 26 8cal cm2 talla xl talla simportadomodelo ttk25 xl rbmarca stancodisponibilidad inmediata',
#  'aromatizador glade aceites esenciales abrazos vainilla repuesto limpieza',
#  'mantas ignifugas 2 mts 2 mts rojas',
#  'botador cilindrico c mango hexagonal 6mm sb 3734n 6 150 bahco mantenimiento',
#  'espatula plastica 4 pulg 14445 truper',
#  'micas a4 termolaminadora 150micras 100 warrior oficina micas a4 termolaminadora 150micras 100 generico',
#  'thinner estandar 1 litro limpieza',
#  'cera limpiadora premio crema limpiadora cream cleanser laptops impresoras equipos electronicos',
#  'carro utilitario servicio 2 repisas 227kg capacidad rubbermaid',
#  'pulsioximetro ri fox n riester seguridad indutrial oximetro contec pantalla spo2 pr barra pulso senal',
#  'frasco vidrio ambar tapa tapon color blanco b 28 120 ml miscelaneos',
#  'cascos seguridad blancos marcas msa bullard 3m',
#  'mica laminadora a4 150 micrones 50 dimerc oficina',
#  '44 cuchilla cutter blister caja 12 eurotools',
#  'llave stillson 12 mantenimiento llave stilson 12 pulg 87 623 stanley pza',
#  'urdidores 2 m mantenimiento urdidores cintura 2 m entrega 15 dias',
#  'saco polipropileno laminado blanco 51cm 84 cm 20 33 logo color costal 2do millar 25 descuento',
#  'bandas adhesivas curitas',
#  'pano microfibra scoth brite 4 limpieza pano microfibra virutex 4',
#  'tacho vaiven color marron residuos organicos 60 l limpieza tacho cosmos color marron residuos organicos 60 l rey plast 2 dias',
#  'barras bi cono amarillo negro seguridad indutrial barra retractil negra amarilla',
#  'silicona acetica blanca sachet 50 gr mantenimiento silicona acetica blanca sachet 50 gr silicona acetica blanca 50gr tekbond',
#  'caja organizadora reyplast megaforte 25 14 2 l sku 22778',
#  'camara hero10 black gopro',
#  '9 nivel 36pulg cuerpo aluminio proteccion abs truper herramietas nivel torpedo magnetico 36 900mm g0904 fixman',
#  'llave francesa 8 pulg stanley mantenimiento',
#  'enmicadora a3 oficina enmicadora a3 razer modelo 320 sistema 4 rodillos diametro rodillos 25mm ancho entrada 320mm calentamiento 3 4 min velocidad laminado 560 mm min grosor micas 80 200 mic temperatura enmicado 100 180degc consumo energia 560w solida estructura metal',
#  'llave hexagonal pavonada torx tr 9 1995 torx t9 mc bahco codigo be 8675 corresponde llaves juego cotiza codigo individual ft adjunta',
#  'set casaca pantalon pvc amarillo 0 32 mm t l seguridad indutrial',
#  'cinta seguridad 2 tamper roja 50m seguridad indutrial cinta seguridad tsg rojo 5cm 50m cinta deja evidencia',
#  'llave mixta 23mm stanley 86 868 mantenimiento',
#  'impresion enmarcado cuadros miscelaneos marco madera pinovidriomedidas 160x120',
#  'galleta club social six pck clasico cafeteria',
#  'rodillos pintar 9 pintura',
#  'cuchilla seguridad sk 9 olfa',
#  'generador gasolina yamaha 7200w modelo ef7200de frecuencia 60 hz 240v peso 94 kg mantenimiento',
#  'sacagrapas',
#  'juego destornilladores combinados 8 5 planos 3 estrellas proto j1208sc mantenimiento jgo 7 destornilladores precision ph 3 plano 4 witte',
#  'televisor samsung smart televisor 82 uhd 4k un82au7000gxpe 2021',
#  '26 tachuela 3 4 100 piezas min 6 cajitas',
#  'dado socket 6 pt enc 3 8 9 16 proto j5218h entrega 3 4 meses mantenimiento',
#  'telwinarrancador cargador probador bateria multifuncional startzilla 3024 tecnologia telwin',
#  'manguera transparente cantidad 3 metros medida 1 4 herramientas',
#  'cajas abisagradas grande',
#  'dado estandar 3 8dr 3 8 6pt proto j5212h mantenimiento dado socket 3 8 dr 3 8 6 pt proto j5212h',
#  'silla fantasy ergonomicaespaldar asiento espuma inyectada depoliuretano 52 kg m3 tapizado tela crepe premium sillas',
#  'guante seguridad black nobuck seguridad indutrial',
#  'caja pilas a2 duracell x8 oficina',
#  'extension vulcanizado opalux 3m 4 tomas enchufe trifasico gris',
#  'cargador baterias 12 24v ruedas bahco bbc420 mantenimiento',
#  'dado punta allen 24mm encastre 3 4 mantenimiento',
#  'rollo etiquetas adhesivas plastificadas ppb 3 1 75mm 25mm 6 000 1 col tuco 3 mantenimiento',
#  'cuchillos imagen referencia adjunto mantenimiento cuchilla p electricista curvo aislado 1000v 2820vpc bahco recubrimiento aislante 3 capas aisladas colores equipos corrientes 1000 v conformidad iec 60900',
#  'frosch pastillas lavavajillas automaticos geschirrspul 26 tabletas limpieza',
#  'maiz molido fino nacional saco 60 kilos',
#  'espatula metalica 4 mango madera tramontina cod 77394105',
#  'pop socket miscelaneos pop socket min 100',
#  'adaptador usb rs232',
#  '7 ciento bolsa negra tacho 75 litros',
#  'chaleco amarillo logo etiqueta seguridad indutrial chalecos industriales corporativostela drill mundo 60 poliester 40 algodon cintas reflectivas forma h 3m bolsilloscolor anaranjado amarillobordado logotipo bordado pecho frase',
#  'ambientador miscelaneos ambientador spray sapolio lavanda frasco 396 ml',
#  'cloruro sodio 0 9 lavado ocular fv 2026 articulos medicos cloruro sodio 0 9 100ml f v 2024',
#  'dado estandar 1 2dr 6 pt 7 8 proto j5428h mantenimiento dado socket 12 pt enc 1 2 7 8 proto j5428',
#  'silla tipo monaco sillas silla estilo monacoestructura fierro redondo pintado horno color negro asiento respaldo tapizado tela unipiel color negrobrazos fierro tapizados',
#  'ensamblaje sillas miscelaneos',
#  'portamachos tipo garrote machos 3 4 3 9 19mm mordazas ajustable man ga 3 4 11437 truper',
#  'lamina polarizada uv 41 82 cm',
#  '30 resaltador amarillo text liner 48 oficina',
#  'rack pedestal 30 60',
#  'tomas electricas estabilizada punto tierra',
#  'jgo desarmadores aislad 1000v 6p bahco 620 6 mantenimiento',
#  'papel toalla nova gigante 1un',
#  'cuchilla 3m mantenimiento cortador 18mm snap off fatmax 10 481 stanley pza stanley sku 123711',
#  'cable red 1 5 metros pack 3 cat 5 mantenimiento',
#  'dado estandar 17mm enc 1 2 6pt proto j7317m',
#  'rollo burbupack 100 10m empaques embalajes',
#  'pasacables 5 canales 90cm ancho 50 cm 5cm alto herramientas',
#  'espatula 4 pulg herramientas espatula flexible 4 cod 14450 truper',
#  'dado estandar 1 2dr 12 pt 1 2 proto j5416h mantenimiento dado pulgadas 1 2 dr 12 pt 1 2 7800dz 1 2 bahco',
#  'llave stillson 12 mantenimiento',
#  'caja bloqueo grupal roja steelpro',
#  'planchas inox 8 8 cm 29 7 cm 2 mm espesor mantenimiento',
#  'audifonos sony mdr zx110ap electricos audifonos over ear sony mdr zx110 negro blanco',
#  'llave mixta 12pt 7mm protoj1207ma mantenimiento llave mixta pulido espejo 12 puntas 7 mm urrea',
#  'lente seguridad dual fit luna oscura msa',
#  'juego plantillas numeros 0 9 alto 2 ancho 1 1 2 miscelaneos',
#  'stretch film indust t 20 20 mic 1 75 kg solpack miscelaneos stretch film indust t 20 20 mic 1 75 kg solpack',
#  'pallets plastico medidas estandar 1m 1 2m plasticos pallets plastico soliplast er 100 3p v1 medidas estandar 100 120 16 cm peso 21 2 kg cap estatica 6000 kg cap estanteria 1300 kg cap dinamica 1500kg',
#  'enmicadora estructura metalica akiles modelo prolam 330 capacidad entrada 33cm formato fotocheck a4 carta oficio a3 control temperatura ajustable bimetalico 4 rodillos silicon ventiladores temperatura laminacion 85 160degc consumo energia 220 vac 600wats',
#  'mini bastidor 4cm mdf miscelaneos mini bastidor redondo diametro interno aprox 4 5cm diametro externo aprox 5cm',
#  'lavavajilla liquida sapolio frasco 750 ml limon ',
#  'llave tubo alta resistencia 8 protoj808hd mantenimiento',
#  'insecticidad matatodo limpieza',
#  'toner hp 414xc w2023xc magenta m454 m479 6000 pag oficina',
#  'esponja celulosa cero rayas scotch brite 3 uni limpieza',
#  'dado estandar 1 2dr 12 pt 3 4 proto j5424h mantenimiento dado 1 2 dr 12 pt 3 4 urrea',
#  'taladro percutor bosch gsb 16 re ruso 750w autolockcod 0601 14e 500 000 sku bshh0079 mantenimiento',
#  'escalera dielec t tijera doble acc fib vidrio170kg 4 pasos colores disponibles amarillo naranja escaleras',
#  'mango extractor pulmones visceras manguera',
#  'televisor 85 smart hdmi samsung televisor',
#  'guante manopla 1 par',
#  'arandela 3 8 herramientas arandelas planas zincado diametro 3 8 kilo 203 uni aprox',
#  'cinta cierre pelo gancho hembra macho x2 x25m',
#  'lavavajillas liquido limon 2 6 lt ayudin limpieza',
#  'silla delphi ii presidente sillas silla delphi ii presidente cabecera regulable sistema reclinable c bloqueo 4 posiciones brazos regulable altura espaldar malla borde pvc asiento acolchado tapizado tela negra apoyo lumbar regulable altura profundidad base dcromada 64 cm 5 puntas garantia 2anos',
#  'alcoholimetro iblow 10 c anti covid mantenimiento alcoholimetro sentech modelo iblow 10 c 05 dias',
#  'guantes anticorte ansell hyflex r 11 318 talla 8 seguridad indutrial',
#  'traje tyvek desechable anaranjado talla l macroguardrx c cinta seguridad indutrial',
#  'esmalte epoxico verde cat epoxico disolv epoxico miscelaneos',
#  'cinta vulcanizantes 3m pieza mantenimiento',
#  'detector voltaje 1000v',
#  'espatula flexible 2 mango ergonomico acero inoxidable usarse alimentos et 2fx 15850 truper',
#  'cafetera 1 7 l 2l cafeteria',
#  'fu2nyl v ht fuelle fu extreme cilindro bucket excavadora cat 374d fl nf 377 65 np fuelle',
#  'linternas cascos 600 lumenes aprox seguridad indutrial',
#  'enchufe ip44 16amp 2p t 250v 6h herramientas',
#  '16 ladrillo pandereta raya piramide 9 11 23 cm 2 2 kilogramos',
#  'dispensadores agua fria caliente bidon oster mantenimiento dispensador agua oster ospwd520w blancodispensador agua mesa temperaturas caliente frio bandeja goteo extraible enfriamiento semiconductor soporta botellones 3 5 galones bloqueo ninos',
#  'corrector 9ml artesco',
#  'ajicero cacer transparente 4 oz tapa plasticos',
#  'galonera gasolina 20 litros 5 gal herramientas',
#  'papel lustre color amarillo',
#  'pistola electrica 1 2 milwaukee mantenimiento pistola llave impacto 1 2 torque 1400ft lbs smart m18 milwaukee cod 1040987',
#  'juego desarmador 6 pzas 00 4 mm mantenimiento',
#  '50 ladrillo pandereta c rayas piramide',
#  'hojas cartulina kimberly a4 220 grs blanco titanio oficina',
#  'televisor lg 65 televisor',
#  'juego desarmador 4 pzas mantenimiento set desarmador acero 4 piezas ubermann',
#  'hidrolavadora mano inalambrica incluye bateria recargable mantenimiento hidrolavadora inalambrica 20v 24 8 bar cargador bateriamarca tools',
#  'frazada banderita 1 1 2 plz',
#  'vendas triangular tela brazo antebrazo utiliza cabestrillo',
#  'tijera oficina flex 8pulg artesco',
#  'rosarios plastico miscelaneos',
#  'cascos seguridad anaranjados marcas msa bullard 3m seguridad indutrial casco modelo h706 naranja 3m',
#  'caja organizadora luxor 15l limpieza caja luxor rey 15l tapas color azul plomo blanco',
#  'tarjetero silicona ii porta celular tarjetero autoadhesivo medidas 9 5 cm 5 7 cm aprox miscelaneos',
#  'plastilina industrial blanca 1 kg',
#  'dado impacto 15 16 3 4 12 ptas imd302a snap on lt 2 dias',
#  'cinta termocontraible blanco 9mm 5 5m dymo rhino 18445 miscelaneos dymo v150009 18445 etiquetas vinilo blanco 3 4 pulgadas negro blanco 2 3 semanas',
#  'silla presidente lims cabecero regulble altura angulo sistema neumatico elevacion altura piston gas sistema reclinacion syncro bloqueo 4 posiciones espaldar malla nylon regulable altura borde polipropileno negro asiento inyectado deslizable profundidad tapizado tela negra carcasa inferior polipropileno negro asiento apoyo lumbar acolchado regulable altura profundidad brazos polipropileno negro regulable 3d altura profundidad angulo base aluminio pulido tipo europa 5 puntas garruchas nylon negro',
#  'linterna frontal recargable cafini luz led fuerte cn l7633c mantenimiento',
#  'bolsa tela logo color negro notex 2 dias',
#  'escobillon industrial 80 cm daryza',
#  'secadora gw 6000 watts negro sku 1000251026 miscelaneos secadora cabello profesional gw 6000 watts negro',
#  'carro utilitario 30 18 38 1 2 cap 227kg urrea 9980 mantenimiento',
#  'camara accion gopro hero 10 black 5 3k 23mp sumergible 10 metros',
#  'alcohol 75 120 ml auxilios',
#  'servicio tapizado sillas servicio tapizado ensamblado colocacion brazos',
#  'pistola neumatica impacto dss 3 4 h herramientas',
#  'cinta embalaje comercial 2 100 yds oficina',
#  'caja ultraforte 6 5 lts rey',
#  'memoria micro sd sony 128gb 90mbps 4k uhs i sr g1uy3a tq',
#  'color rojo fresa quimicos',
#  'llave mixta 12pt 14mm proto j1214masd mantenimiento',
#  'guante hyflex 11 318 recubrimiento corte 3',
#  'aceitera mantenimiento',
#  'placas acero 0 6 mm grosor medida 2 1 5 corte calado letras z 0 9 diseno indicacion miscelaneos',
#  'set desarmadores precision 6 piezas 0 4 mm ubermann',
#  'disco separadores concreto 2 cm bolsa 50 mantenimiento separador plastico circular 20mm 100',
#  'nivel torpedo magnetico 12 300mm g0902fixman herramietas',
#  'engrapadores tipo alicate rapid oficina engrapadores tipo alicate rapid',
#  '12 jabon liquido rosas galon daryza',
#  'tapa bandeja antiderrame prevencion hdpepolietileno hdpe 2 00mm espesor medida 0 62mt 0 52mt 0 10mt altura',
#  'secador botas aire forzado aceroinoxidable totalmente hermetico placado 24 pares saf bt 24estructura robusta fabricada acero inoxidable aisi 304 316 acuerdo aplicacion proteccion cortocircuito sobrecarga electrica proteccion diferencial corriente sistema puesta tierra resistencias tubulares encendido sencillo selector 2 posiciones boton parada emergencia luz piloto verde indica encendido resistencias luz piloto rojo indica presencia energia electrica controlador temperatura digital configurado alta eficiencia secado botas trabajadore mina 1 modulo 24 paresvoltaje 220v monofasica potencia 4 5kw 5kwcertificado garantia 1 ano entrega 4 5 semanas aclarar detalles',
#  'papelera clin reyplast 12 5l color gris modelo retangular pedal plasticos',
#  'maiz molido fino nacional quimicos 3 maiz molido fino nacional sacos 60 kg',
#  'abus candado dielectrico 1 5 amarillo',
#  'insecticida sapolio mata cucarachas hormigas 360ml limpieza insecticida spray mata cucarachas 360 mlsapolio',
#  'esmalte epoxico verde cat epoxico disolv epoxico',
#  'estuche plumones vidrios borrables 6 oficina',
#  'televisor smart 70 samsung lg televisor televisor samsung led 4k uhd smart 70 un70au7000wifi integrado sibluetooth integrado sipuerto usb sientrada hdmi sipuerto ethernet',
#  'cinta embalaje transparente pegafan eco pack 6 empaques embalajes cinta embalaje pegafan cristal 2 x110 yrd rollo',
#  'multi card reader astrom at1005 mantenimiento',
#  'estante herramientas cerrado metal 1000 500 2000 mm metalmecanico',
#  'porta punta 1 4 estandar',
#  'enmicadora tamano a4 termolamindos enmicadora metalica anti atoro ancho entrada 230mm grosor laminado 2mm velocidad 0 5m min temperatura 80 180 numero rodillos 4 alimentacion 220v 60hz 50 enmicadoras micas sencillo dimensiones 400 x200 90 mm oficina enmicadora a4 metal tower 4 rodillosmaquina enmicadora a4 4 rodillosmarca towerequipo tamano completoestructura metal trabajos fuertesenmica tamanos pequenos maximo a4lamina frio calorcon boton reversa enmicado rapido trabajos exigentesgarantia 1 ano detalles ela4 05 maquina enmicadora a4 full metal capacidad lamina 75 mc 200 mc velocidad 500mm minutos regulador temperatura perilla temperatura 90o 150oc ancho maximo lamina 242 mm rodillos 4 piezas espera aprox 5min medidas 410 208 110mm potencia 420w peso 5 5 kg contamos repuestos',
#  'silla ejecutiva cabecera',
#  'cinta masking tape azul scotch blue 48 mm 54 8 m 3m oficina cinta masking tape azul scotch blue 48 mm 54 8 m',
#  'embudo aceite miscelaneos',
#  'reduccion pvc sp 1 1 4 3 4 iny',
#  'cooler tipo maleta nylon medidas 31x22x26cm aprox miscelaneos crepier lonchera ramz coated gr azul material poliester color azul dimensiones 24 60 14 00 26 00 cm',
#  'cuchara mesa 1 3mm 111 cafeteria',
#  'repuesto jabon liquido antibacterial aval lavanda limpieza jabon liquido aval tocador sachet 800 ml lavanda',
#  'taladro inalambrico bosch industrial perfore metal mantenimiento taladro percutor bosch gsb 16 re ruso 750w autolockcod 0601 14e 500 000 sku bshh0079',
#  'rotuladores vidrio x6 cloth estuche maped oficina rotuladores vidrio x6 cloth estu',
#  'caja megaforte 50 c tapa cjx033000 transparentes plasticos caja organizadora 50 c ruedas qplast',
#  '70 tazon bowl acero inoxidable 18 cm herramietas bolo inox mezclad profund 18',
#  'lampara inspeccion luz led ajustable recargable 37 5 cm 0 35cm dimetro fuentes luz cob entrada 5v 1a brillo cob 700 lumenes max led life 10 000 horas bateria 3200 mah 10 horas base magnetica 360 deg disponible 20 dias aprox mantenimiento',
#  'llave hexagonal pavonada torx t15 1995torx t15 bahco codigo be 8675 corresponde llaves juego cotiza codigo individual ft adjunta mantenimiento',
#  'tela marron 1 70 ancho',
#  'pistola electrica 3 4 milwaukee',
#  'hervidor electrico oster 1 7l 2143573 negro electricos',
#  'esmalte epoxico verde cat epoxico disolv epoxico miscelaneos jgo epoxico titanic verde cromo epx 6100 gl catalizador disolvente',
#  'termoradiador 11 celdas orange modelo ny2311 16m votlaje 220v 60hz potencia 2300w electricos termoradiador 11 celdas orange modelo ny2311 16m potencia 2300w',
#  'sillas ergonomicas ruedas giratorias sillas',
#  'licencia adobe ilustrator miscelaneos licencia anual adobe illustrator digital mac windows 1pc',
#  'camara digital cybershoot sony dsc w800 zoom optico 5x negro',
#  'silla twig cajera giratoria sillas',
#  'marcador recargable pizarra acrilica jumbo 123r negro',
#  'filtro 2097 p100 alivio niveles molestos vap org ozono 3m filtro particulas 2097 p100 3m tm usarse solidos surgen procesamiento minerales carbon hierro metales algodon harina sustancias particulas liquidas base oleosa sprays emitan vapores nocivos humos metalicos producidos soldaduras autogenas soldaduras fuertes cortes otrasoperaciones incluyan calentamiento metales materiales radiactivos particulados amianto vapores organicos debajo limite exposicion permisible pel osha segunlas normas gubernamentales vigentes resulte inferior',
#  'bandeja antiderrame prevencion polietileno hdpe 2 00mm espesor laterales 4mm base 2mm espesor medida 25cm 30cm 10cm',
#  'sillas ada brazos sillas',
#  'planta artificial palmera 120 cm miscelaneos',
#  'limpiador zocalos 3m limpieza limpiador zocalos 3m',
#  'bandeja fierro aluzinc 60x50x30 cm 0 5mm w tools 2 3 dias mantenimiento',
#  'sikament 290 n 4 l pet',
#  'bandejas geomembranas 1m 1m 20 cm',
#  'vaso descartable transp 6oz pqt 50un',
#  'neumatico p carretilla mantenimiento',
#  'glade aromatizante paraiso azul limpieza',
#  'franela boreal amarilla bolsa 2un 32 5 cm 43 cm 2 limpieza',
#  'notas adhesiva 3x3 cubo 500 hojas 5 colores',
#  'tachos residuos',
#  'pinzas bloqueo bloqueo to safety tenaza bloqueo revestido vinilo 1 5 codigo ts sh02',
#  'aspiradora ind chasquy mod 7h55 motor 3x1200w 55 glns accesorios estandar mantenimiento aspiradora industrial chasquy mod 7h55 motor 3x1200w capac 55 glns accesorios estandar agarradera curva 1 20 mts manguera flexible 3 mts escobilla limpiar filtro accesorio plano barrer agua alfombra 03 motores 1200 watts 220v 60 hz sensores temperatura',
#  'pico kit antiderrame antichispas mantenimiento pico antichispa mango fibra vidiro farmesa',
#  'juego 13 llaves hexagonal l punta bola rack urrea',
#  'carteles acrilico 1m 1m miscelaneos carteles acrilico 1m 1m 4mm grosor',
#  'guantes nitrilo talla m pack 100 sku 2166674 articulos medicos guantes nitrilo talla m caja 100 family doctor',
#  'dado socket 6 pt enc 3 8 3 8 proto j5212h entrega 3 4 meses mantenimiento',
#  'dispensador agua cafeteria',
#  'jgo destorn aislado 1000v 5p be 9882s bahco alternativacodigo 135007 mantenimiento',
#  'mota pizarra acrilica artesco color azul pano industrial anti polvo antipolilla oficina mota pizarra acrilica artesco color azul',
#  'caja bajalenguas fv 2026',
#  'pqt cucharitas',
#  'frasco iodopovidona solucion 60 cc seguridad indutrial frasco iodopovidona solucion 60 cc',
#  'laminas termicas pvc espesor 1 5 mm ancho 200mm transparente incoloro 05 11 15 3 05 alto riel acero',
#  'guantes touch n tuff talla m limpieza guantes nitrilo descartable ansell modelo 92 600 talla m',
#  'guia auxilios miscelaneos',
#  'ratchet cabeza pera 3 8 7 proto j529 mantenimiento ratchet matraca liberacion rapida cabeza pera encastre 3 8 7 acero cromo vanadio m 5249 13659 truper',
#  'uhu barra x21 gr oficina',
#  'esmalte epoxico amarillo cat epoxico disolv epoxico mantenimiento juego epoxico anypsa titanic 03 componentes 1 gln amarillo md ral 1003 gl catalizador disolvente',
#  'abus candado aluminio 3 dorado golden llave unica foto',
#  '43 listones encofrado roble 2 1 2 espesor 2 1 2 ancho 10 pies longitud herramientas',
#  'soldimix solditac 30 cc miscelaneos',
#  'brady caja bloqueo estandar metal rojo cod 65699',
#  'cafetera thomas th 138i 900w 12 tazas cafeteria',
#  'alicate universal aislado ega 76607',
#  'plumon pizarra recargable negro wbma vbm pilot oficina plumon pizarra v board master wbma negro 1 unidad',
#  'botellas pulverizadoras vidrio ambar vacias etiquetas botella 16 oz',
#  'candado brady master lock azul 1 77 x1 5 mantenimiento 99556 brady candado seguridad 1 5 azul',
#  'llave stillson 24 87 626 stanley mantenimiento',
#  'persiana medidas 1 5 alto 1 6 ancho',
#  'escaleras dielec tipo avion fibra vidrio170kg 4 pasos 1 05mt alt plataforma modelo hesc fv 10 04 ia horn',
#  'caja metalica tipo gabinete 6 gavetas sata',
#  'lubricante multiusos wd 40 11 onzas mantenimiento lubricante wd 40 11 oz',
#  'juego machuelos tarrajas 76 piezas codigo 12443 truper miscelaneos',
#  'cinta lana color verde sintetica 7 5m',
#  'aceite pino 85 quimicos',
#  'detector tormeta storm pro 2 bateria 9 v cargador 9x16x5cm seguridad indutrial',
#  'wincha acer 5mt 3 4 glob plus 30 615 stanl 6',
#  'cartucho 6003 vapores organicos gases acidos 3m seguridad indutrial',
#  'azucar 1 kilogramo cafeteria azucar 1 kilogramo tottus',
#  'cable profibus dp electric 5 conductor 20 awg profibus shielded 100 v 6es7 194 1ly10 0aa0 electricos',
#  'pistola grasa electrica 18v 10 000 psi 2 vel baterias voltaje 18v presion maxima 10000 psi 69 mpa longitud manguera 1200 mm capacidad cartucho 450 g maximo volumen 295 ml mincuenta modos velocidad baja automatica tipo grasa compatible nlgi 0 2conjunto montaje barril 450g 191a81 2 manguera flexible 1200 mm 191a79 9 cinturon hombro 166094 6 estuche transporte 821840 1 disponibilidad inmediata',
#  'caja cosechera calada 40 litros rey caja plastica',
#  'plancha espuma plastazote cod m6030 30mm 1 18 alta densidad',
#  'persiana vertical pvc 1 m 1 m color blanco adjunto',
#  'krea funda almohada lisa 50 70 cm 144 hilos azul pack 2 miscelaneos',
#  'codo pvc 1 45 pulg embone p agua termoformado tubo pavco',
#  'clips metalico 1 tam 33mm caja 100 oficina clips nro 1 cajax100und artesco 33mm 100',
#  'alicate pela cables stripping 160mm wiha',
#  'torquimetro tipo click conex 1 cap 300 2000 lb pie williams',
#  'mesa abatible rodante 1 40m 0 60m facil plegado almacenamiento conveniente ahorro espacio ruedas garantizan facil movilidad caracteristicas tablero melamine 25 mm canto grueso 3mm base soporte magnesio 3 0mm pintura polvo horno color blanco travesano acero laminado frio 2 3 mm espesor recubrimiento polvo columna aluminio 1 8mm pintura polvo horno color blanco garrucha tipo europa doble goma freno 2 pulgadas sistema facil plegado mano muebles',
#  'botas caucho segusa rgb punta acero talla 39 seguridad indutrial',
#  'vinifan oficio oficina forro transp artesco of 5mt',
#  'streamlight protac hl r usb headlamp 1 000 lumens',
#  'interruptor conmutacion empotrado bticino mantenimiento',
#  'pano seca scotch brite',
#  'ruedas fijas carritos porta herramientas 80 mm 200 mm 70 230 kg mantenimiento ruedas fijas carritos porta herramientas 80 mm 200 mm 70 230 kg',
#  'recogedor hude limpieza recogedor plastico hude',
#  'mochila targus groove 15 6 black cvr600',
#  'caja grapas kp grapas 26 6 5000 oficina',
#  'candado 70mm',
#  'escaleras pasos werner capacidad 375 libras escaleras escalera tipo banco 3 pasos capacidad carga 375 libras werner 3 dia',
#  'kit antiderrame implementado nacional incluye respirador via km 329 guantes nitrilo lentes seguridad claro anti impacto cordones absorbentes 3m piezas bolsas negras descartables polietileno trapo industrial pano absorbente traje descartable bandeja antiderrame acero',
#  'manometro digital fluke 700g 10000 psi',
#  '3 escalera tipo avion 3 pasos aluminioaltura base superior 0 75 cmancho escalera 75cmmarca rex ladder cap carga 200 kgfabricacion nacionalcertificacion unitiemp entrega 7 dias escaleras',
#  'alicate mecanico 8 203mm m negro stanley 84 098 mantenimiento',
#  'cincel hexagonal punta aguda 1 1 8 28 6mm 520mm makita',
#  'placas trabajadas plancha acero satinado calidad 304 7x5cm 1mm espesor incluye grabacion sistema laser quemado identificacion codigo qr individualizados cinta doble contacto 3m pegados posterior',
#  'caja d 12 12 12 cm incluye logo ferreyros lados empaques embalajes',
#  'tubo 3 8 1m doblar estribos 6mm mantenimiento',
#  'mug ecologico',
#  'espejo redondo inspeccion 78 241',
#  'opcion 1 45371228 jarro 11onz recto apilable loza blanca 737 cafeteria',
#  'extension corriente retractil',
#  'barra plastico retractil rojo blanco 2 2 mt plasticos',
#  'notas adhesivas post it 655 3 5 color oficina notas adhesivas post it 655 3 5 color',
#  'armario muebles',
#  'casco tipo sombrero v gard fas trac iii c porta lampara seguridad industrial',
#  'lampara inalambrica minera wisdom modelo 4a 03',
#  'hilo mouline anchor color amarillo cod 291 miscelaneos hilo mouline anchor color amarillo cod 291',
#  '24 disco separador construccion ds150 paquete',
#  'papel lustre color amarillo cat oficina papel lustre color amarillo cat paq 50',
#  'rack pared tv65 miscelaneos',
#  '26 cajas tachuelas',
#  'horno microondas electricos horno microondas lg mh6536gis 25 litros easyclean',
#  '35 arco sierra fijo profesional stanley herramietas',
#  'silla rudy alta br reg sillas silla rudy alta br reg',
#  'garruchas giratorias 2 1 2 32mm rueda poliuretano naranja c carga 60 kg c u',
#  'pabilo delgado menor ndeg 20',
#  'llave stilson 36 kamasa mantenimiento',
#  'juego llaves allen 13 pzas 0 50 3 8 proto j4983 mantenimiento',
#  'estufa gas dual alfano 4200w ld 168gqf negro',
#  'mochila reforzada rigida laptops tapa dura reforzada impermeable mochilas mochila targus intellect essential laptop 15 6 negro resistente agua',
#  'tachos residuos solidos c tapa ruedas cartones color azul plasticos tacho recolector ecologico sistema pedal 240 lt color blanco azul negro rojo marron 840 ohsa 18001 ce iso9001 iso 14000',
#  'inflador pie herramientas inflador pedal truper 60 psi',
#  'persiana vertical pvc 1 m 1 m color blanco miscelaneos',
#  '15 papel higienico jumbo sumac dorado 6 x550 limpieza',
#  'bandeja metalica c asas galvanizada 1 20 espesor medidas 0 40m 0 40m 0 28m mantenimiento',
#  'taladro percutor 1 2 gsb 18v 50 2 baterias l case',
#  'tomacorriente industrial',
#  'neceser pochteca miscelaneos neceser pochteca min 100',
#  'par pilas duracel aaa x2',
#  'lockers 3 cuerpos 3 casilleros columna lockers locker metalico modelo mk3 03 09 puertas',
#  'estuche pana acuerdo trofeo miscelaneos',
#  'bidon agua incluyendo bidon',
#  'lapicero pilot frixion clicker blrt fr7 borrable 0 7 rojo blister',
#  'reloj digital pared calendario tempe 36cm x15cm',
#  'escalera alumino 5 pasos',
#  'dado impacto corto enc 1 1 2 36mm ozat mantenimiento',
#  'cable adaptador usb 2 0 macho serial rs232 db9 macho generico glink computo',
#  'parafina chi25kfr5860 quimicos',
#  'codo pvc 3 45 pulg embone p agua pavco mantenimiento codo 3 45 desague pavco',
#  'oxido magnesio quimicos',
#  'martillo bola mango fibra vidrio 32 oz proto j1332pgd mantenimiento',
#  'linea aire mantenimiento',
#  'estabilizador voltaje cdp 4 tomas 4usb 600va 300w ru avr604i cdp mantenimiento',
#  'pqt cinta adhesiva pegafan 1 2 25yrd caja 12 oficina pqt cinta adhesiva pegafan 1 2 25yrd caja 12',
#  'tag metalico datos c pasador metalico reforzado ancho 4 5cm 6 5 cm mantenimiento tag metalico datos ancho 4 5cm 6 5 cm relieve cable precinto seguridad 10cm',
#  'silla prisma',
#  'juego 3 tapers',
#  'trapeador balde seguridad indutrial',
#  'tacho megaforte 220 rotulado plasticos blanco plasticos tacho recolector megaforte 220 rotulado plasticos',
#  'folder sujetador color anaranjado oficina',
#  'papel bond fotocopia extra blanco alcalino 80 grs pqtx 500 hojas atlas office oficina papel bond a4 80 g pqt 500 hojas extra blanco alcalino atlas',
#  'llave stillson 8 redline mantenimiento',
#  'portaherramientas 20 mantenimiento caja herramientas metalica stanley fmst20061',
#  'aceitera manual 680 ml c pico flexible surtek mantenimiento',
#  'lamina polarizada uv 40 5 81 5 cm',
#  'lustramueble pride 400 ml limpieza lustra mueble pride 400 ml',
#  'caja 500 gr homai w p miscelaneos homai w p presentacion caja 500 g',
#  'caja lapiceros negro faber castell 035',
#  'multimetro digital fluke 101',
#  'goniometro digital electricos',
#  'tubos led philips 16 w 1600 lumen luz fria t8 1200 mm 220 v',
#  'cuchillo cartonera 01gl l5 kamasa km108',
#  'protector cable caucho sbr 2 canales dimensiones 100 25 5 cm resistencia 7 toneladas mantenimiento',
#  'llave exagonal mm 9 pzas bondhus 12299',
#  'bineria 1 alto laminas termicas pvc espesor 1 5 mm ancho 200mm transparente incoloro 2 13m 8 42m 2 lados 16 84m',
#  'pila a2 duracell 4 oficina',
#  'binocular canon 10x42 l is wp miscelaneos 1 binocular canon 10x42 l is wp estabilizacion imagen',
#  'dado estandar 1 2dr 6 pt 1 proto j5432h mantenimiento dado socket 1 2 dr 6 pt 1 proto j5432h entrega 3 4 meses 6pt',
#  'jgo dados pta hexagonal 3 8dr 4 10mm 4 5 6 7 8 9 10 proto j4990 sma mantenimiento jgo dados pta hexagonal 3 8 dr 4 10mm 7 piezas stanley proto j4990 smaentrega 20 25 dias',
#  'colchones plaza media miscelaneos modelo luana marco espuma 1 5 plz',
#  'adaptador manguera 5 8 rosca 1 2 macho mantenimiento adaptador manguera 5 8 pulg rosca 1 2 pulg macho',
#  'conexion rapida tipo hembra tipo c acero inoxidable 1 mantenimiento',
#  'pistola llave impacto 1 2 torque 1400ft lbs smart m18 milwaukee mantenimiento',
#  'tecle senorita 6 ton 3 mts cadena mammut mantenimiento',
#  'botador 3734 2mm bahco mantenimiento botador 3734 2mm bahco recto',
#  'hidrolavadora inalambrica dhw080zk 18vx2 makita 1 multicargador doble dc18rd 2 baterias bl1830b 2 3 dias',
#  'escalera telescopica 20 pasos escaleras escalera telescopica 20 pasos',
#  'acero longitudinal corrugada construccion grado 60 fy 4200 diametro 3 8 viga portico mantenimiento barra acero corrugado construccion astm a615 grado 60 diametro 3 8 9m sider peru',
#  'escalera dielec t tijera acceso fib vidrio136kg 04 pasos ansi14 5 modelo hesc fv 4 4 ia horn color amarillo',
#  'dado estandar 1 2dr 6 pt 1 proto j5432h',
#  'bolsa tela drill modelo medidas 33cm 28 5cm color oscuro 02 dias',
#  'enchufe ip44 16amp 2p t 250v 6h',
#  'lavaojos portatil 14gl encon queda satock',
#  'ponchos agua talla m baratos miscelaneos',
#  'panel led cuadrado luz fria 60x60cm 40w 6500k 220v falke miscelaneos',
#  'pulidor polvo sapolio frasco 450 gr bano azul',
#  'cortina bano extra gruesa 180x180cm pepelma',
#  'ltc pinza bloqueo psl 1 s n panduit bloqueo abus pinza bloqueo traba 1 0 pack 5',
# ...
#  'dado std tubular 3 8 17mm 6pt proto j5017mh mantenimiento',
#  'opc 1 dispositivo bloqueo baterias bloqueo ts epl01m to safety bloqueo enchufes 110 220v etiqueta peligro',
#  'cera liquida master pisos laminados galonera 1l',
#  'ventilador pie metal 3 1 18 wurden gsm 18 3 caja control 3 velocidades estructura metalica aspas aluminio suman 18 45 cm ancho altura ventilador regulable base tipo rueda asegura estabilidad ventilador diametro 18 velocidades 3potencia 100 wnumero aspas 3material metalmanual armado siprocedencia chinatipo ventilador 3 1 18 mantenimiento',
#  'panasonic camara lumix dmc fz300 12 1mp',
#  'bandeja rejilla color amarillo fabricado resina poliester ug adicionada aditivos uv fibra fibra vidrio mat 450 gr m2 antiacida tipo ecr 730 mm ancho 630 mm altura 120 mm altura 1 1 2 grating color amarillo mantenimiento',
#  'lector memoria astrom at 1005 sd micro sd m2 mantenimiento lector multitarjetas astrom externo at100',
#  'pack x15 agua mesa gas san luis botella 750ml cafeteria',
#  'televisores smart lg 55 pulgadas televisor televisor lg led 65 uhd 4k smart televisor 65up7750 2021',
#  'espiral anillar color negro numero 25mm bolsa 100',
#  'regla irrompible 30cm surtido oficina',
#  'cable red utp cat 6 sellado testeado rj45 5 metros generico mantenimiento',
#  'venda elastica 6 x5 alkhofar f2024 articulos medicos',
#  'abus candado dielectrico arco 3 0 azul',
#  'silla delphi ii presidente espaldar malla poliester borde pvc cabecera malla regulable altura angulo apoyo lumbar regulable altura profundidad asiento interno acolchado tapizado tela negra asiento externo pvc negro apoyo lumbar regulable altura angulo brazo regulables pvc base aluminio cromada 5 puntas sistema reclinacion bloqueo sistema neumatico elevacion altura piston gas',
#  'insecticida sapolio mata cucarachas hormigas 360ml',
#  'bolsas basura negra daryza 180 lt c f pqt 10',
#  'detergente sapolio 14 kilos limpieza detergente sapolio 13 5 kilos',
#  'mesa catering plegable 150cm sm color blanco material polietileno peso 9 5 kg caracteristicas estructura acero mesa hdpe garantia 1 ano',
#  'papel toalla nova gigante 1 limpieza papel toalla nova gigante 1',
#  'agregado construccion arena gruesa saco 40 kg',
#  'envase descartable transparente 4 oz ajicero tapa plasticos taper tapa ajicero 4 onzas 100 transparentes',
#  'cinta adh cristal 3 4x36 yrd tuco plast pegafan',
#  'venda elastica 2 auxilios',
#  'enfriador portatil 35 50m2 mantenimiento',
#  'sierra copa bi metal 2 1 2 herramientas',
#  'taper vidrio rectangular 1000 ml gyg miscelaneos',
#  'cinta embalaje 2 40 yds pegafan oficina cinta embalaje 2 40 yds pegafan 6',
#  'cable xtech xtc 307 usb 2 0 macho b macho oficina',
#  'papel toalla scott calorie absorb 65 hojas paquete 4un limpieza',
#  '26 cajas tachuelas limpieza tachuela 6 caja 465 gr',
#  'parihuela soliplast er 100 sd v1 negro cod 110210011 cap estatica 4000 kg cap estanteria 800 kg cap dinamica 1200kg queda stock disponible plasticos',
#  'etiquetadora tze fx221 brother 9 mm black on white oficina etiquetadora tze fx231 brother 12 mm black on white',
#  'candado brady master lock amarillo seguridad indutrial y434697 brady candado seguridad arco 3 0 amarillo',
#  'juego destornillador allen mango t punta bola 6pz 3 10mm 42b 6 b irimo mantenimiento',
#  'espuma poliuretano 1m 1 5m 1 60kg m3 bellsafe 50 kg m3 ncr 0 36 autoextiguible autoadhesiva',
#  'silla lims gerencial sillas',
#  'linea aire mantenimiento linea aire estandar flujo demanda premaire cadet cilindro escape 10 minutos',
#  'candados bloqueo color rojo nylon 99570 brady',
#  'kit convertidor voltaje dd12 24 168 alfatronix',
#  'osciloscopio portatil fluke 190 502 s',
#  'limpia vidrios sapolio lavanda gatillo 650ml',
#  'calefactor portatil electrico wurden 1500 w vidrio templado pn1500glf electricos wurden codigo 113095693 panel convector wurden 1500w vidrio templado pn1500glf',
#  'escalera 3 pasos baranda material fierro rueda retractil',
#  'bolsas rojas gruesas 6 micras 150 litros 36 45 plasticos bolsas rojas gruesas 6 micras 150 litros 36 45 millar',
#  'lapicero negro oficina lapicero faber ec 034 negro p media',
#  'quitasarro kazvel galon 3 8 lt registro sanitario',
#  'alicate mecanico 8 1 16 proto j278g mantenimiento',
#  'adaptador pvc 2 pulg p agua pavco mantenimiento',
#  'megafono',
#  'rtetlvtp tl wa801n tl wa801n access point 300mbps 2 4ghz 2',
#  'dispensdor alcohol gel multiflex blanco',
#  'extension encastre 1 2 5 proto j5461 mantenimiento extension encastre 1 2 5 proto j5461',
#  'yugo doble gancho 5ton mantenimiento',
#  'botella alcohol 70deg 500ml manos chisguete pulverizador contenido envase limpieza',
#  'frazadas campamento',
#  'grapas galvanizadas 26 6 x5000 artesco oficina',
#  'limpia vidrios bio daryza gatillo 1 lt limpieza',
#  'cocina induccion record 2106800003 10 funciones negro potencia 2000wtipo energia electricaacero inoxidable base induccion acero esmaltado aluminio fundido base induccion',
#  'dado impacto tubular enc 1 38mm',
#  '43 kit pistola riego 6 funciones 4 piezas conectar plastico miscelaneos',
#  'cinta embalaje 2 x40 yd econ transp pegafn 770 oficina',
#  'periodico mural bolsillos acrilico 5mm 1 70m 0 8 m',
#  '43 tronzadora metales electrica 14pulg 2400w 220v bosch herramietas',
#  'guantes nitrilo talla m pack 100 sku 2166674',
#  'bolsas plasticas rollo transparente 10 15',
#  'codo pvc 1 1 4 90 pulg embone p agua pavco mantenimiento',
#  'horno microondas oster 20 l pogme2702 negro electricos horno microondas 20l oster pogme2702 negro',
#  'estabilizador voltaje cdp r avr1808i 1800va 1000w 8 tomas salida',
#  'seguridad industrial',
#  'silla atlantis giratoria sillas silla atlantis giratoria negra espaldar malla nylon negra soporte lumbar fijo borde polipropileno negro asiento espuma laminada costura tapizado tela malla negra sistema neumatico elevacion altura piston gas sistema reclinacion basculante bloqueo 90 grados ajuste tension brazos fijos polipropileno negro base metalica cromada 5 puntas 60 cm ruedas goma 50 mm piso duro peso maximo soportado 120 kg',
#  'detergente marsella profesional bolsa 13 5 kg',
#  'embudos plastico flexibles plasticos',
#  'aerosol multiusos wd 40 5 5 oz limpieza aerosol multiusos wd 40 5 5 oz',
#  'audifonos overhead inalambrico wh ch710n c bluetooth nfrasco negro electricos audifonos inalambricos noise cancelling wh ch710n negro garantia 6 meses 2 dias',
#  'locker 3 cuerpos 2 casilleros lockers',
#  'sillas ergonomicas sillas silla giratoria lyon negro',
#  'glicerina 1 kg fratello',
#  'bandeja contencion aceite 2 gal mantenimiento bandeja antiderrame prevencion polietileno hdpe 2 00mm espesor laterales 4mm base 2mm espesor medida 25cm 30cm 10cm',
#  'probeta graduada polipropileno 10ml isolab',
#  'plumon recargable indeleble negro oficina pliumon indeleble 23 jumbo faber castell negro 12',
#  'silla lims gerencial similar sillas silla delphi ii gerente sistema reclinable syncro c bloqueo 4 posiciones brazos regulable altura espaldar malla borde pvc asiento acolchado tapizado tela negra apoyo lumbar regulable altura profundidad base aluminio 64 cm 5 puntas garantia 2 anos disponible 3 semanas',
#  'juegos paletas pare siga seguridad indutrial juegos 2 paletas pare siga senal seguridad informativa mango madera paleta hexagonal doble cara cara pare cara sigaaltura 46 7 ancho 29 cm',
#  'frasco kartell pp 50 ml boca ancha graduado cod 1621 plasticos',
#  '10 jersey blanco 10 jersey rojos plasticos new jersey color blanco rojo',
#  'traje cinta reflectiva blanco anaranjado talla xxl worksafe',
#  'lavavajilla liquido sapolio ultra 5 litros ',
#  'tacho pedal acero inoxidable limpieza',
#  'pqt cinta adhesiva pegafan 1 2 25yrd caja 12',
#  'casco seguridad h700 blanco 3m',
#  'casio xr 12we1 negro blanco 12mm ez label',
#  'cajas luxor 12 l caja plastica caja organizadora luxor 12 l',
#  'silla rudy alta tapizada tela negra brazos regulables altura base nylon sillas',
#  'llave sacar filtro aceite lona 6 stanley 78 230 mantenimiento',
#  'tubo pvc sap 1 1 2pulg 3mts miscelaneos',
#  'frigobar 95l lh electronic plateado electricos',
#  'aire acondicionado split contenedor logistica considerar calefaccion mantenimiento',
#  'mochila porta laptop swissgear modelo wenger ibex black navy mochilas mochila wenger ibex',
#  'manguera incendio nitrilo 1 1 2 300 psi color rojo 30 mts acople bronce extremos firehouse',
#  'manometro digital fluke 700g 10000 psi mantenimiento',
#  'pqts folder manila tamano oficio oficina pqts folder manila 25 tamano oficio',
#  '25 disco madera 4 1 2 30t',
#  'saco dormir klimber rango temperatura 0degc 10oc material poliester',
#  'tomas electricas estabilizada punto tierra electricos',
#  'cintillos sujetacable color negro 100mm x100und mantenimiento',
#  'organizadores articulos limpieza limpieza soporte organizador escobas',
#  'adaptador pvc 3 pulg p agua pavco',
#  'portwest st36 55gr m2 mono vistex sms tipo 5 6 talla l seguridad indutrial',
#  'codo pvc 1 1 2 45 pulg embone p agua pavco mantenimiento',
#  '40 cepillo tamizador alambre malla fina',
#  'pqt hoja bond a4 oficina oferta pqt hoja bond a4',
#  'mdtech espanta zancudos 1l',
#  'jgo 9 llaves allen plegables stanley mantenimiento juego 9pza llave allen plegable pro 5 64 1 4 pulg 69 265 stanley jgo stanley sku 91251',
#  'silla venso rta 4570 negro silla presidencial malla nylon brazos regulables silla presidencial respaldar malla nylon marco nylon soporte lumbar acolchado tapizado malla regulable profundidad angulo cabecera acolchada tapizada malla regulable altura angulo asiento acolchado tapizado malla nylon sistema lap doble palanca ajuste tension posicion brazos nylon regulables altura base cromada garruchas goma',
#  'equipos',
#  'estabilizador cdp r avr1808i pro 1800va 1000w 8 salidas electricos',
#  'cinta metrica wincha global plus 5mts stanley 30 615 mantenimiento',
#  'raid max 400ml limpieza insecticida spray raid maxcucarachas aranas fra 360 ml',
#  'extension domestica blanca 3mts calibre 2x16 fp0103 fulgore',
#  'enmicadora a3 seguridad indutrial enmicadora cbit modelo a3 330c 4 rodillos entrada 330mm',
#  'cinta seguridad 2 tamper roja 50m seguridad indutrial',
#  'sabanas polares 1 5 plaza',
#  'cocla cafe tradicion cusco 220g',
#  'algodon 50g',
#  'esmalte epoxico amarillo cat epoxico disolv epoxico mantenimiento jgo epoxico titanic amarillo md ral 1003 gl catalizador disolvente',
#  'banditas adhesivas curitas',
#  'lavavajillas limon sapolio ultra contenido 750ml',
#  'inclinometro digital masterlevel box pro interfaz bluetooth transferencia datos medicion flipdisplay realizan mediciones cabeza pantalla gira automaticamente pantalla iluminada leer situacion funcion calibracion recalibrar sensor aumentar seguridad mediciones funcion hold mantener medido actual pantalla pantalla iluminacion potente iman fijacion compacto formato mini',
#  'bloqueo tipo cable imagen adjunto',
#  'codo pvc 4 45 pulg embone p agua pavco',
#  'ducha emergencia seguridad industrial le030 ducha lavaojos acero inoxidable cl 001i haws avlis',
#  'tollas humedas 80 toallitas ninet',
#  'tela drill 100 algodon color marron 1 70 ancho mundo',
#  'rollos etiquetas plastificada zebra zt410 miscelaneos',
#  'llave mixta 12pt 5 16 proto j1210a',
#  'insecticida elimina voladores spray 400ml lata 400 ml  insecticida spray sapolio frasco 360 ml matatodo',
#  'poncho impermeable talla m calidad seguridad indutrial national geographic poncho prueba agua verdemedidas 127 ancho 102 cm material 100 pvc espesor 0 22 0 25 mm',
#  'bidon perfumador lavanda',
#  'monofasicos trifasicos',
#  'cascos seguridad anaranjados marcas msa bullard 3m seguridad indutrial',
#  'algodon natural 4 hebras miscelaneos algodon natural 4 hebras ovillo 300 metros 100gr pack 10 ovillos material algodon tanguis 100 color crudomodelo h 1200composicion algodon tanguis 100 ancho diametro 10 cmhecho perumarca sierra craftalto 7 cm',
#  'aromatizador liquido glade aceites naturale abrazos vainilla repuesto 21 ml pack 3 limpieza repuesto aromatizador glade abrazos vainilla pqt 3un',
#  'philips tubo fluorescente led ecofit 16w 6500k 1600lm 220v luz fria mantenimiento',
#  'oximetro pulso dedo contec 2 dias',
#  'reduccion pvc sp 2 1 2 pulg p agua termoformado tubo pavco',
#  'btbsign contador led caja interruptor sistema gestion produccion visual remota pantalla 4 pulgadas 4 digitos contador perfecto produccion visitantes evento regazo pantalla led alto brillo digitos 4 pulgadas recuento maximo 9999 contador aumentara disminuira recuperara descontara 1 active interruptor encendido apagado suministrado cliente zumbador pitira numero cambie subir bajar numero especificofacil instalacion soportes montaje incluidos montaje pared viene cable 4 metros puedes extender cable funciones 1 contador baja 1 activa interruptor encendido apagado suministrado cliente 2 contador aumentara disminuira 1 cliente pulse boton abajo mando distancia inalambrico 3 restablecer cero caja interruptor mando distancia 4 recuento abajo 1 especifico caracteristicas ic alta velocidad pantalla led alto brillo 4 digitos 4 estabilidad fuerte anti interferencia especificaciones altura digital 4 0 in led rojo abajo interruptor mando distancia inalambrico rango visualizacion 0 9999 dimensiones totales 16 9 6 5 1 6 in adaptador corriente ac dc toma corriente estandar 120 vacsoporte montaje incluido montaje pared pqt incluye 1 contador led 1 caja interruptor 1 cable senal 9 8 ft 1 adaptador ac dc soportesmanual usuarionota incluye bateria cr 2025 3v',
#  'escalera f vidrio 10 pasos 3 05mt doble acceso 136kg america vulcano escaleras',
#  'silla visita modelo avant',
#  'panel led rc048 60x60 luz fria 36w 6500k philips',
#  'aposito hemostatico celox auxilios',
#  'pack mata insectos vol 400ml raid max 400ml limpieza pack insecticida raid elimvol 400 raid max 400',
#  'manguera aire 1 2 30 mts terminales prensado extremos hembra macho 180 psi mantenimiento',
#  'mando colgante control tecles 05 botones modelo 4713 seguridad indutrial caja colg 4bt 1velo pe xaca4713 schneider electric disponibilidad 6 7 semanas oc',
#  'calculadora 8 digitos ms 8s ms 8b',
#  'caja bloqueo metalica rojo 65699a bradlock bloqueo',
#  'termoventilador t ceramico imaco tc 3116',
#  'brady ribbon 4400 blanco 2 x150 bmp71 miscelaneos',
#  'thinner acrilico 3 5 litros mantenimiento thinner kusa galon',
#  'cargador samsung micro usb v8 travel adapter 2 blanco electricos cargador samsung micro usb v8 travel adapter 2 blanco',
#  'base laptop cooler airboom boreal ab 18 soporta laptop 17 computo',
#  'termo doite 750 ml acero acepta cafeteria thermos r 1000ml black acero',
#  'toalla papel scott premium absorb 65hj bol 4und',
#  'rubber mallet',
#  'silla ergonomica modelo delphi gerente syncro brazos 3d sillas',
#  'pegamento 60ml uhu n 13 pegalotodo oficina pegamento 60ml uhu n 13 pegalotodo',
#  'jgo dados torx 1 4dr t10 t30 proto 10 15 20 25 27 30 proto j4739c mantenimiento jgo dador torx 1 4dr t10 t15 t20 t25 t27 t30 williams',
#  'estuche plumones vidrios borrables 6 oficina plumon indeleble faber winer 52 negro xund',
#  'corrector t lapicero faber 9ml x12 pqt',
#  'inspection mirror mantenimiento espejo redondo inspeccion 78 241',
#  'dado std tubular 3 8 15mm 6pt proto j5015mh mantenimiento',
#  'silla modelo galassia syncro',
#  'cooler igloo polar 100qt 150 qt totalmente aislado',
#  'lamina polarizada uv 40 5 81 5 cm 2 cm corte jonhson window films 5 miscelaneos',
#  'frascos 1lt atomizador plasticos gatillo spray plastico pulverizador repuesto azul rojo amarillo p boca 28',
#  'impresora epson l3150 wifi oficina',
#  'camarote premier 1 5 plz metal campamento',
#  'regla metalica 30cm',
#  'tag metalico datos ancho 4 5cm 6 5 cm relieve cable precinto seguridad 10cm mantenimiento',
#  'sikasil universal 280 ml caja 12',
#  'brother hse 221 cinta tubotermocontraible termocontraible 8 8mm 1 5 mts texto negro fondo blanco',
#  'jaladores agua 90 cm limpieza',
#  'lustra muebles pride 400ml limpieza',
#  'planta filodendro 100 cm',
#  'pinzas bloqueo modelo adjunto pdf indicar medidas bloqueo to safety tenaza bloqueo revestido vinilo 1 5 codigo ts sh02',
#  'lector tarjetas memorias micro sd cf sd ms usb 3 0 ugreen 30333 electricos',
#  ...]

# %%
# CREAR VECTORES
def create_vectors(data):
    """
    Crea gensim vectors
    ** data: list of words normalized and without stop words
    """

    # Split data
    texts = []
    for producto in data:
        if isinstance(producto,str) and len(producto)>0: 
            producto_split = producto.split(" ")
            palabras = []
            for word in producto_split:
                word = word.strip()
                
                if len(word) > 0:
                    palabras.append(word)
            texts.append(palabras)

    # Create wordVector
    cores = multiprocessing.cpu_count()
    w2v_model = Word2Vec(min_count=3,
                            window=2,
                            vector_size=500,
                            sample=6e-5,
                            alpha=0.03,
                            min_alpha=0.0007,
                            negative=20,
                            workers=cores-1)
    w2v_model.build_vocab(texts)
    w2v_model.train(texts, total_examples=w2v_model.corpus_count,epochs=30)

    # Save data
    w2v_model.wv.save_word2vec_format("data/vectores.txt")

# %%
create_vectors(TRAIN_DATA)

# %%
# COPIAR VECTORS EN MODELO DE SPACY
def load_word_vectors():

    model_name = "./model"

    nlp = spacy.blank("es-419")
    nlp.to_disk(model_name)


    subprocess.run([sys.executable,"-m","spacy",
                    "init", "vectors","es","data/vectores.txt",model_name])

# %%
load_word_vectors()
# Out:
# ℹ Creating blank nlp object for language 'es'
# [2023-07-01 15:07:55,827] [INFO] Reading vectors from data/vectores.txt
# 13341it [00:00, 13910.03it/s]
# [2023-07-01 15:07:56,837] [INFO] Loaded vectors from data/vectores.txt
# ✔ Successfully converted 13341 vectors
# ✔ Saved nlp object with vectors to output directory. You can now use
# the path to it in your config as the 'vectors' setting in [initialize].
# /Users/chavezmunoz.a/Documents/Dev/FacilInsumos/Historial/model

# %%
# USAR LISTA DE PRODUCTOS OFRECIDOS PARA CREAR INDICE
def create_index(df_productos):

    # Load model
    nlp = spacy.load("./model")

    # Get data from df
    train_list = df_productos[["Norm_Producto Ofrecido","TRAZA"]].values.tolist() 
    train_list = dict(zip(df_productos["TRAZA"], df_productos["Norm_Producto Ofrecido"]))

    # Create annoy object
    annoy_index = AnnoyIndex(500,'euclidean')

    # Make a dictionary for reference data
    reference = {}

    # For every produtct
    for ix,(traza,text) in tqdm(enumerate(train_list.items())):
        if text != None:

            # Convert to vector
            doc = nlp(text) 

            # Add to annoy index
            annoy_index.add_item(ix, doc.vector)

            # Add data to reference dictionary
            reference[ix] = (traza,text)
    annoy_index.build(10)

    # Save data
    annoy_index.save('./data/product_index.ann')

    with open("./data/reference_map.json", "w",encoding="utf-8") as f:
        json.dump(reference, f, indent = 4)
   
    return

# %%
create_index(df_productos)
# Out:
# 8344it [00:00, 8769.82it/s]

# %%
# Descargar script
# !jupyter nbconvert --to python actualizar_datos.ipynb
# Out:
# [NbConvertApp] Converting notebook actualizar_datos.ipynb to python
# [NbConvertApp] Writing 7968 bytes to actualizar_datos.py
